# %% [markdown]
# <a href="https://colab.research.google.com/github/932244priti/Data-Analytics-Project/blob/main/piechart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Sample data for the pie chart
data = {'Category': ['A', 'B', 'C', 'D'],
        'Value': [30, 20, 15, 35]}
df = pd.DataFrame(data)

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(df['Value'], labels=df['Category'], autopct='%1.1f%%', startangle=140)
plt.title('Sample Pie Chart')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data for the pie chart
data = {'Category': ['maya', 'varsha', 'pratiksha', 'aishwarya'],
        'Value': [55, 89, 56, 35]}
df = pd.DataFrame(data)

# Create the pie chart
plt.figure(figsize=(6, 8))
explode = (0.1, 0, 0, 0)  # Explode the first slice (priti)
plt.pie(df['Value'], labels=df['Category'], autopct='%1.1f%%', startangle=70, colors=['gray', 'blue', 'pink', 'yellow'], explode=explode, shadow=True)
plt.title('student chart')hi
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.legend(df['Category'], title="Categories", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3747361954.py in <cell line: 0>()
#       4 data = {'Category': ['maya', 'varsha', 'pratiksha', 'aishwarya'],
#       5         'Value': [55, 89, 56, 35]}
# ----> 6 df = pd.DataFrame(data)
#       7
#       8 # Create the pie chart
#
# NameError: name 'pd' is not defined
